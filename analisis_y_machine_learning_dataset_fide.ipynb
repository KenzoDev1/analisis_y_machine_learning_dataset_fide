# %% [markdown]
# <a href="https://colab.research.google.com/github/KenzoDev1/analisis_y_machine_learning_dataset_fide/blob/main/analisis_y_machine_learning_dataset_fide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 13 (delta 8), reused 13 (delta 8), pack-reused 0 (from 0)
# Unpacking objects: 100% (13/13), 1.80 KiB | 307.00 KiB/s, done.
# From https://github.com/kenzodev1/analisis_y_machine_learning_dataset_fide
#  * branch            main       -> FETCH_HEAD
#    f48308c..d5fc53f  main       -> origin/main
# Updating f48308c..d5fc53f
# Fast-forward
#  .../conf/base/catalog.yml                          |  7 +++
#  .../conf/base/parameters.yml                       |  1 +
#  .../pipelines/unsupervised_learning/nodes.py       | 50 +++++++++++++++-------
#  .../pipelines/unsupervised_learning/pipeline.py    |  2 +-
#  4 files changed, 43 insertions(+), 17 deletions(-)

# %%
# Clona tu repositorio
# !git clone https://github.com/kenzodev1/analisis_y_machine_learning_dataset_fide.git
# Out:
# Cloning into 'analisis_y_machine_learning_dataset_fide'...
# remote: Enumerating objects: 199, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 199 (delta 23), reused 50 (delta 15), pack-reused 115 (from 1)
# Receiving objects: 100% (199/199), 87.73 MiB | 46.24 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# Cambia el directorio de trabajo a la raíz de tu proyecto Kedro
# %cd analisis_y_machine_learning_dataset_fide/analisis_y_machine_learning_dataset_fide
# Out:
# /content/analisis_y_machine_learning_dataset_fide/analisis_y_machine_learning_dataset_fide

# %%
# Instalar las dependencias directamente desde tu requirements.txt
# !pip install -r requirements.txt

# %%
# Desactiva la telemetría de Kedro mediante variable de entorno para la sesión actual
# %env KEDRO_TELEMETRY_OPT_OUT=true

# Desactiva la telemetría a nivel de configuración del proyecto
# !kedro telemetry opt-out
# Out:
# env: KEDRO_TELEMETRY_OPT_OUT=true
# [05/14/26 18:03:00] INFO     Using 'conf/logging.yml' as logging ]8;id=794425;file:///usr/local/lib/python3.12/dist-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=957928;file:///usr/local/lib/python3.12/dist-packages/kedro/framework/project/__init__.py#275\275]8;;\
#                              configuration. You can change this
#                              by setting the KEDRO_LOGGING_CONFIG
#                              environment variable accordingly.
# Usage: kedro [OPTIONS] COMMAND [ARGS]...
# Try 'kedro -h' for help.
#
# Error: No such command 'telemetry'.
# [05/14/26 18:03:01] INFO     Kedro is sending anonymous usage data ]8;id=890240;file:///usr/local/lib/python3.12/dist-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=145763;file:///usr/local/lib/python3.12/dist-packages/kedro_telemetry/plugin.py#242\242]8;;\
#                              with the sole purpose of improving
# ...

# %%
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project
from pathlib import Path

project_path = Path.cwd()
bootstrap_project(project_path)

with KedroSession.create(project_path=project_path) as session:
    # Esto ejecutará todo, igual que 'kedro run'
    session.run()
# Out:
# [05/14/26 18:03:03] INFO     Using 'conf/logging.yml' as logging configuration. You can change this ]8;id=996766;file:///usr/local/lib/python3.12/dist-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=304824;file:///usr/local/lib/python3.12/dist-packages/kedro/framework/project/__init__.py#275\275]8;;\
#                              by setting the KEDRO_LOGGING_CONFIG environment variable accordingly.
# [05/14/26 18:03:04] INFO     Kedro project analisis_fide_chess                                       ]8;id=757649;file:///usr/local/lib/python3.12/dist-packages/kedro/framework/session/session.py\session.py]8;;\:]8;id=530259;file:///usr/local/lib/python3.12/dist-packages/kedro/framework/session/session.py#337\337]8;;\
# ...
